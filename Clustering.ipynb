# %% [markdown]
# <a href="https://colab.research.google.com/github/hbtgit/Project/blob/main/Clustering.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
import matplotlib.cm as cm
from sklearn.cluster import KMeans
from sklearn.preprocessing import LabelEncoder

# %%
# Load your data
X = pd.read_csv('Result.csv')

# %%
kmeans = KMeans(n_clusters=3, random_state=2)

# %%
pred = kmeans.fit_predict(X[[ 'Score']])
pred
kmeans.cluster_centers_
print(kmeans.cluster_centers_)
# Add the cluster labels to the DataFrame
X['Cluster'] = pred
# Out:
# [[ 3.19166667]
#  [16.33      ]
#  [ 7.975     ]]

# %%
X.to_csv('clusters.csv', index=False)
plt.figure(figsize=(12, 8))
plt.scatter(X['Age'], X['Score'], c=pred, cmap='rainbow')
plt.xlabel('Age')
plt.ylabel('Score')
plt.title('K-Means Clustering')
plt.show()
